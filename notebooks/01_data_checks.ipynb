# %% [markdown]
# # Import library & inspect dataset

# %%
import pandas as pd

df = pd.read_csv("../data/raw/serie_a_last_5_seasons_matches.csv")
df.head()
# Out:
#          date      home_team  away_team  home_goals  away_goals
# 0  2020-09-19  Hellas Verona       Roma         3.0         0.0
# 1  2020-09-19     Fiorentina     Torino         1.0         0.0
# 2  2020-09-20          Genoa    Crotone         4.0         1.0
# 3  2020-09-20       Sassuolo   Cagliari         1.0         1.0
# 4  2020-09-20       Juventus  Sampdoria         3.0         0.0

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1806 entries, 0 to 1805
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1806 non-null   object
#  1   home_team   1806 non-null   object
#  2   away_team   1806 non-null   object
#  3   home_goals  1806 non-null   float64
#  4   away_goals  1806 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 70.7+ KB
# date          0
# home_team     0
# away_team     0
# home_goals    0
# away_goals    0
# dtype: int64
